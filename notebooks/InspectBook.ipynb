# %%
import pandas as pd
df = pd.read_csv("../data/processed/final_dataset.csv")
df.head()
# Out:
#        DATE  REALPRICE  HousingStarts  MedianHouseholdIncome  MortgageRate  \
# 0  1/1/2015   69375.58           1085                56470.0         3.670
# 1  2/1/2015   69740.21            886                56470.0         3.710
# 2  3/1/2015   70079.37            960                56470.0         3.770
# 3  4/1/2015   70498.60           1190                56470.0         3.672
# 4  5/1/2015   70736.26           1079                56470.0         3.840
#
#    Population  UnemploymentRate
# 0   27468.531               4.5
# 1   27468.531               4.5
# 2   27468.531               4.5
# 3   27468.531               4.4
# 4   27468.531               4.4

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

df["DATE"] = pd.to_datetime(df["DATE"])

plt.plot(df["DATE"], df["REALPRICE"])

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.xticks(rotation=45)
plt.title("Real Housing Price Over Time")
plt.show()
